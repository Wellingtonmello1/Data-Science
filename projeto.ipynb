# %%
import pandas as pd

# %%
rating = pd.read_csv('/workspaces/Data-Science/dados/ratings.csv')

# %%
rating
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
rating.shape
# Out:
# (100836, 4)

# %% [markdown]
# alterar nome das colunas

# %%
rating.columns   = ["id_user", "filme_id", "nota", "momento"]
rating.head()
# Out:
#    id_user  filme_id  nota    momento
# 0        1         1   4.0  964982703
# 1        1         3   4.0  964981247
# 2        1         6   4.0  964982224
# 3        1        47   5.0  964983815
# 4        1        50   5.0  964982931

# %%
rating["nota"].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
rating["nota"].value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
rating["nota"].mean()
# Out:
# np.float64(3.501556983616962)

# %% [markdown]
# PLOT PARA GRAFICOS

# %%
rating["nota"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
rating["nota"].median()
# Out:
# np.float64(3.5)

# %%
mediana = rating["nota"].median()
media = rating["nota"].mean()
print(f'Mediana é {mediana} e a média é {media}')
# Out:
# Mediana é 3.5 e a média é 3.501556983616962

# %%
rating["nota"].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(rating["nota"])
# Out:
# <Axes: ylabel='nota'>

# %%
rating
# Out:
#         id_user  filme_id  nota     momento
# 0             1         1   4.0   964982703
# 1             1         3   4.0   964981247
# 2             1         6   4.0   964982224
# 3             1        47   5.0   964983815
# 4             1        50   5.0   964982931
# ...         ...       ...   ...         ...
# 100831      610    166534   4.0  1493848402
# 100832      610    168248   5.0  1493850091
# 100833      610    168250   5.0  1494273047
# 100834      610    168252   5.0  1493846352
# 100835      610    170875   3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
filmes =pd.read_csv('/workspaces/Data-Science/dados/movies.csv')

# %%
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes.columns = ["filme_id", "titulo", "generos"]
filmes.head()
# Out:
#    filme_id                              titulo  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
rating.head()
# Out:
#    id_user  filme_id  nota    momento
# 0        1         1   4.0  964982703
# 1        1         3   4.0  964981247
# 2        1         6   4.0  964982224
# 3        1        47   5.0  964983815
# 4        1        50   5.0  964982931

# %% [markdown]
# JOINS ENTRE RATING E FILMES

# %%
rating.query("filme_id == 1")
# Out:
#        id_user  filme_id  nota     momento
# 0            1         1   4.0   964982703
# 516          5         1   4.0   847434962
# 874          7         1   4.5  1106635946
# 1434        15         1   2.5  1510577970
# 1667        17         1   4.5  1305696483
# ...        ...       ...   ...         ...
# 97364      606         1   2.5  1349082950
# 98479      607         1   4.0   964744033
# 98666      608         1   2.5  1117408267
# 99497      609         1   3.0   847221025
# 99534      610         1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
rating.query("filme_id == 2")["nota"].mean()
# Out:
# np.float64(3.4318181818181817)
